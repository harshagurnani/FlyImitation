# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.deg2rad(np.linspace(0,360,100))

# %%
def gauss(x,w,b):
    z = w*x + b
    return np.exp(-z**2)

# %%
m = np.deg2rad(30)
std = 1

w = 1/std
b = -m/std

#for b in np.linspace(-.2,.2,30):
#    plt.plot(y,gauss(y,w,b))
for jj in np.linspace(-2,2,30):
    #b = -jj*m/std
    #
    b = -m/std + jj
    plt.plot(y,1-gauss(y,w,b), 'b')
    plt.plot(y,1-gauss(y,-w,b), 'k')
plt.plot([m,m],[0,1],'r--')
plt.plot([3.14,3.14],[0,1],'r--')

# %%
std
# Out:
# 0.2
